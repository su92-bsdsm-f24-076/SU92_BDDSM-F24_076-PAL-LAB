# %%
# Import required libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Create a blank white canvas
canvas = np.ones((400, 600, 3), dtype="uint8") * 255

# Write text "PYTHON" on the canvas
cv2.putText(canvas, "PYTHON", (120, 200),
            cv2.FONT_HERSHEY_SIMPLEX, 2,
            (0, 0, 255), 3, cv2.LINE_AA)

# Convert image to grayscale
gray_image = cv2.cvtColor(canvas, cv2.COLOR_BGR2GRAY)

# Apply Gaussian Blur
blur_image = cv2.GaussianBlur(gray_image, (7, 7), 0)

# Apply edge detection
edges = cv2.Canny(blur_image, 60, 160)

# Display results
plt.figure(figsize=(10,5))

plt.subplot(1,3,1)
plt.title("Original Image")
plt.imshow(cv2.cvtColor(canvas, cv2.COLOR_BGR2RGB))
plt.axis("off")

plt.subplot(1,3,2)
plt.title("Grayscale Image")
plt.imshow(gray_image, cmap="gray")
plt.axis("off")

plt.subplot(1,3,3)
plt.title("Edge Detection")
plt.imshow(edges, cmap="gray")
plt.axis("off")

plt.show()

# %%
canvas = np.ones((300, 300, 3), dtype=np.uint8) * 255

cv2.line(canvas, (50, 50), (250, 50), (255, 0, 0), 2)
cv2.rectangle(canvas, (50, 100), (150, 180), (0, 255, 0), 2)
cv2.circle(canvas, (200, 140), 40, (0, 0, 255), 2)
cv2.putText(canvas, 'OpenCV', (80, 250), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0), 2)

plt.imshow(cv2.cvtColor(canvas, cv2.COLOR_BGR2RGB))
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Create a blank image
img = np.ones((300, 500, 3), dtype=np.uint8) * 255

# Write text on image
cv2.putText(img, "PYTHON", (100, 150),
            cv2.FONT_HERSHEY_SIMPLEX, 2,
            (0, 0, 255), 3)

# Apply Gaussian Blur
blurred = cv2.GaussianBlur(img, (5, 5), 0)

# Show image
plt.imshow(cv2.cvtColor(blurred, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
edges = cv2.Canny(img, 100, 200)
plt.imshow(edges, cmap='gray')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Create a white image
img = np.ones((300, 500, 3), dtype=np.uint8) * 255

# Add text
cv2.putText(img, "PYTHON", (120, 160),
            cv2.FONT_HERSHEY_SIMPLEX, 2,
            (0, 0, 0), 3)

# Convert image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Apply threshold
ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# Display result
plt.imshow(thresh, cmap='gray')
plt.axis("off")
plt.show()
